# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\harsh\Downloads\spotify dataset.csv")
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
df.track_name=df.track_name.fillna("VACUUM")
df.track_artist=df.track_artist.fillna("VACUUM")
df.track_album_name=df.track_album_name.fillna("VACUUM")

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  0
# track_artist                0
# track_popularity            0
# track_album_id              0
# track_album_name            0
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
df1=df.sort_values('track_popularity',ascending=False).head(1500)
df1
# Out:
#                      track_id  \
# 20091  2XU0oxnq2qxCpomAAuJY8K
# 1551   2XU0oxnq2qxCpomAAuJY8K
# 30202  696DnlkuDOXcMAnKlTgXXK
# 23104  696DnlkuDOXcMAnKlTgXXK
# 21468  696DnlkuDOXcMAnKlTgXXK
# ...                       ...
# 4647   4hQ6UGyWQIGJmHSo0J88JW
# 4001   4fwo6czG5nvOQMzhOto1ya
# 11095  3V8UKqhEK5zBkBb6d6ub8i
# 1381   0vrmHPfoBadXVr2n0m1aqZ
# 30451  2tpWsVSb9UEmDRxAl1zhX1
#
#                                               track_name    track_artist  \
# 20091                                       Dance Monkey     Tones and I
# 1551                                        Dance Monkey     Tones and I
# 30202                                            ROXANNE  Arizona Zervas
# 23104                                            ROXANNE  Arizona Zervas
# 21468                                            ROXANNE  Arizona Zervas
# ...                                                  ...             ...
# 4647   Back To You - From 13 Reasons Why – Season 2 S...    Selena Gomez
# ...

# %%
plt.scatter(df1.instrumentalness,df1.energy)

# %%
from sklearn.cluster import KMeans
kmeans_model=KMeans(n_clusters=5)
kmeans_model.fit(df1[["instrumentalness","energy"]])
# Out:
# C:\Users\harsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\harsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
kmeans_model.cluster_centers_
# Out:
# array([[0.00174622, 0.6780794 ],
#        [0.01461114, 0.35899317],
#        [0.00704908, 0.83002168],
#        [0.00190851, 0.53624466],
#        [0.4705    , 0.38475   ]])

# %%
df1["cluster_group"]=kmeans_model.labels_

# %%
x=df1.iloc[:,12:]
x
# Out:
#        energy  key  loudness  mode  speechiness  acousticness  \
# 20091   0.588    6    -6.400     0       0.0924        0.6920
# 1551    0.588    6    -6.400     0       0.0924        0.6920
# 30202   0.601    6    -5.616     0       0.1480        0.0522
# 23104   0.601    6    -5.616     0       0.1480        0.0522
# 21468   0.601    6    -5.616     0       0.1480        0.0522
# ...       ...  ...       ...   ...          ...           ...
# 4647    0.724    6    -4.856     1       0.0486        0.0945
# 4001    0.717    1    -5.121     1       0.0573        0.0620
# 11095   0.675   11    -3.445     0       0.2140        0.5420
# 1381    0.873    9    -5.650     1       0.0275        0.0715
# 30451   0.705    1    -4.972     0       0.0382        0.0654
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 20091          0.000104    0.1490    0.513   98.027       209438
# 1551           0.000104    0.1490    0.513   98.027       209438
# ...

# %%
df1["cluster_group"].value_counts()
# Out:
# 0    525
# 3    426
# 2    368
# 1    161
# 4     20
# Name: cluster_group, dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x="instrumentalness",y="energy",data=df1,hue="cluster_group")
# Out:
# <Axes: xlabel='instrumentalness', ylabel='energy'>

# %%
df2=df1.loc[:,['instrumentalness','energy']]
df2
# Out:
#        instrumentalness  energy
# 20091          0.000104   0.588
# 1551           0.000104   0.588
# 30202          0.000000   0.601
# 23104          0.000000   0.601
# 21468          0.000000   0.601
# ...                 ...     ...
# 4647           0.000002   0.724
# 4001           0.000000   0.717
# 11095          0.000013   0.675
# 1381           0.009820   0.873
# 30451          0.000000   0.705
#
# [1500 rows x 2 columns]

# %%
matrix=df2.corr()
matrix
# Out:
#                   instrumentalness    energy
# instrumentalness          1.000000 -0.180997
# energy                   -0.180997  1.000000
